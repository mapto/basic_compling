# %% [markdown]
# Further information:
# https://realpython.com/natural-language-processing-spacy-python/

# %% [raw]
# !python -m spacy download en_core_web_sm

# %%
from collections import Counter

import spacy
# Out:
# /home/mapto/.local/lib/python3.10/site-packages/torch/cuda/__init__.py:546: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
# models need to be installed first
# see https://spacy.io/models
nome_modello = "en_core_web_sm"
nome_file = "data/Head_1666.txt"

n = 3

# %%
with open(nome_file) as f:
    text = f.read()

# %%
nlp = spacy.load(nome_modello)
doc = nlp(text)

# %%
num_gram = Counter()
cgram = []
for token in doc:
    if token.is_punct:
        cgram = []
        continue
    if len(cgram) == n - 1:
        num_gram[" ".join(cgram + [token.lower_])] += 1
    cgram = cgram[-(n - 1) :] + [token.lower_]

num_gram
# Out:
# Counter({'i could not': 28,
#          '\n ◊ \n': 23,
#          'so that i': 21,
#          'according to the': 15,
#          'that i was': 15,
#          'as well as': 14,
#          'which made me': 14,
#          '\n and so': 13,
#          'and that i': 13,
#          'i thought it': 13,
#          'and with that': 13,
#          '\n in the': 13,
#          'it is a': 12,
#          'by which means': 12,
#          'and so i': 12,
#          'it may be': 12,
#          'i told him': 12,
#          'as soon as': 11,
#          'but i was': 11,
#          '\n how he': 11,
#          'and that he': 11,
#          'that i could': 11,
#          '\n i was': 11,
#          '\n there is': 10,
#          'for i was': 10,
#          '\n i had': 10,
#          'i would have': 10,
#          'but that i': 10,
#          'i resolved to': 10,
#          'to the intent': 10,
#          '\n and \n': 9,
#          'that it was': 9,
#          'and in a': 9,
#          'at last i': 9,
#          'i had not': 9,
#          'that they were': 9,
#          'i can not': 9,
#          'that i would': 9,
#          'as if i': 9,
#          'said \n i': 9,
#          'but that he': 8,
#          'which he did': 8,
#          'neither could i': 8,
#          'not so much': 8,
#          'i was not': 8,
#          '\n the next': 8,
#          'and that the': 8,
#          '\n it is': 8,
#          'i knew not': 8,
#          'and at last': 8,
#          'i told her': 8,
#          'in the mean': 8,
#          'it was my': 8,
#          'and so we': 8,
#          'but could not': 8,
#          'the next day': 8,
#          '\n that he': 7,
#          'so that we': 7,
#          'i was forced': 7,
#          'in the morning': 7,
#          'but more especially': 7,
#          'then did i': 7,
#          'but i had': 7,
#          'they would have': 7,
#          'so that now': 7,
#          'and by the': 7,
#          'but if you': 7,
#          'that he was': 7,
#          'and that she': 7,
#          'after i had': 7,
#          'i began to': 7,
#          'i askt him': 7,
#          'that i might': 7,
#          'that i had': 7,
#          '\n a \n': 6,
#          'that he had': 6,
#          'but that which': 6,
#          'it will be': 6,
#          'there was a': 6,
#          '\n and the': 6,
#          'as for my': 6,
#          'but it was': 6,
#          'i had no': 6,
#          'which put me': 6,
#          'that we could': 6,
#          '\n or a': 6,
#          'and in the': 6,
#          'which was the': 6,
#          'i went to': 6,
#          '\n and that': 6,
#          'i thought my': 6,
#          '\n in this': 6,
#          'i thought i': 6,
#          'i must needs': 6,
#          'but when i': 6,
#          'by this time': 6,
#          'that i thought': 6,
#          'that they would': 6,
#          '\n but to': 6,
#          'neither did i': 6,
#          'in the first': 6,
#          '\n unnumbered page': 5,
#          '\n from \n': 5,
#          '\n it was': 5,
#          '\n or \n': 5,
#          'and \n page': 5,
#          'i know not': 5,
#          'but would not': 5,
#          'by reason of': 5,
#          '\n by this': 5,
#          'give me leave': 5,
#          'that there was': 5,
#          'of which i': 5,
#          'when i was': 5,
#          'there is no': 5,
#          'i saw a': 5,
#          'which i did': 5,
#          'and therefore would': 5,
#          'i was so': 5,
#          'and with much': 5,
#          'i should have': 5,
#          'and i shall': 5,
#          'we had not': 5,
#          'and therefore i': 5,
#          'she had not': 5,
#          'having so done': 5,
#          '\n the \n': 5,
#          'as i thought': 5,
#          'there was no': 5,
#          '\n where i': 5,
#          'i desired her': 5,
#          'but that they': 5,
#          'since it is': 5,
#          'c. \n i': 5,
#          '\n said he': 5,
#          'and that my': 5,
#          'and the like': 5,
#          'we betook our': 5,
#          'that she was': 5,
#          '\n i am': 5,
#          'after he had': 5,
#          'she would have': 5,
#          '\n he is': 5,
#          'and as he': 5,
#          'and if you': 5,
#          'which i knew': 5,
#          'had i not': 5,
#          'he told me': 5,
#          'yet i could': 5,
#          'it was the': 5,
#          '\n said she': 5,
#          'that he would': 5,
#          'that he may': 5,
#          '\n what a': 5,
#          'which was to': 5,
#          'that he should': 5,
#          'as i was': 5,
#          'i chanced to': 5,
#          'and thus it': 5,
#          'at first i': 5,
#          'as it is': 5,
#          'i found my': 5,
#          'there was not': 5,
#          'if i would': 5,
#          'one of the': 5,
#          'it was but': 5,
#          'came to me': 5,
#          'for there was': 5,
#          'and that if': 5,
#          'now did i': 5,
#          'then would i': 5,
#          'but at last': 5,
#          'but that the': 5,
#          'and yet i': 4,
#          'that i have': 4,
#          'for it is': 4,
#          '1 page duplicate': 4,
#          'that is to': 4,
#          'that he might': 4,
#          'and in order': 4,
#          '\n where he': 4,
#          'but i shall': 4,
#          'but what was': 4,
#          'i shall give': 4,
#          'without the least': 4,
#          '\n in a': 4,
#          'and that which': 4,
#          'can not but': 4,
#          '\n where we': 4,
#          'and in this': 4,
#          'and to the': 4,
#          'if i had': 4,
#          'who was very': 4,
#          'not knowing what': 4,
#          'the master of': 4,
#          'that she would': 4,
#          'i took my': 4,
#          '\n i took': 4,
#          'i was very': 4,
#          'c. \n and': 4,
#          'and with a': 4,
#          'when they are': 4,
#          'that in a': 4,
#          '\n i shall': 4,
#          'the next morning': 4,
#          '\n that is': 4,
#          'which was in': 4,
#          '\n which is': 4,
#          'that if i': 4,
#          '\n after this': 4,
#          'which they did': 4,
#          'with that i': 4,
#          '\n i would': 4,
#          'and as i': 4,
#          'but they were': 4,
#          'it is no': 4,
#          'and it is': 4,
#          'lest i should': 4,
#          'as if it': 4,
#          'and by that': 4,
#          'and would not': 4,
#          'that i must': 4,
#          '\n to which': 4,
#          '\n we had': 4,
#          'by that time': 4,
#          'when i saw': 4,
#          'but there was': 4,
#          'but at length': 4,
#          'i got a': 4,
#          'for it was': 4,
#          '\n i could': 4,
#          '\n with that': 4,
#          'i thought good': 4,
#          'and so went': 4,
#          '\n i went': 4,
#          'we could not': 4,
#          'desiring me to': 4,
#          'and so with': 4,
#          'that they had': 4,
#          'which having done': 4,
#          'and so it': 4,
#          'that at last': 4,
#          'since i had': 4,
#          'so that my': 4,
#          'whilst i was': 4,
#          'to which i': 4,
#          'and i would': 4,
#          'desiring him to': 4,
#          'i had now': 4,
#          'i pretended to': 4,
#          'i bid him': 4,
#          'with that he': 4,
#          '\n now did': 4,
#          '\n my master': 4,
#          'and if that': 4,
#          'and would have': 4,
#          'and that they': 4,
#          'i would not': 4,
#          'if you are': 4,
#          'that i should': 4,
#          'for they are': 4,
#          'i gave him': 4,
#          'but not without': 4,
#          '\n he that': 3,
#          '\n this is': 3,
#          '\n the english': 3,
#          '\n but let': 3,
#          'for he was': 3,
#          'i could never': 3,
#          'and then for': 3,
#          'though ever so': 3,
#          'that we were': 3,
#          '\n but since': 3,
#          'and those that': 3,
#          'as the \n': 3,
#          'not without some': 3,
#          'which was made': 3,
#          'as if they': 3,
#          'it had been': 3,
#          'which made her': 3,
#          'this course i': 3,
#          'that they could': 3,
#          'and so much': 3,
#          'in this manner': 3,
#          'which i understood': 3,
#          'i was sent': 3,
#          'and making a': 3,
#          'just as the': 3,
#          'till i was': 3,
#          'it was not': 3,
#          'at length he': 3,
#          'before i could': 3,
#          'i should be': 3,
#          'had not the': 3,
#          'with which he': 3,
#          'and when he': 3,
#          'by telling her': 3,
#          'a great many': 3,
#          'to see how': 3,
#          'this was the': 3,
#          'and so be': 3,
#          'it was no': 3,
#          'being in a': 3,
#          'telling me it': 3,
#          'and that made': 3,
#          'that they might': 3,
#          'and if i': 3,
#          'that for her': 3,
#          'and what i': 3,
#          '\n as soon': 3,
#          'and many times': 3,
#          'as if he': 3,
#          'that what ever': 3,
#          'we can not': 3,
#          '\n bing out': 3,
#          '\n when they': 3,
#          '\n upon the': 3,
#          'and therefore resolved': 3,
#          'as i am': 3,
#          'at last the': 3,
#          'to tell you': 3,
#          'and the other': 3,
#          'one would have': 3,
#          'and i will': 3,
#          'i got my': 3,
#          'that she could': 3,
#          'but in fine': 3,
#          'but that it': 3,
#          'that i verily': 3,
#          'i was resolved': 3,
#          'and therefore desired': 3,
#          'which you may': 3,
#          '\n there was': 3,
#          'but i could': 3,
#          'that i soon': 3,
#          '\n that i': 3,
#          'i acquainted my': 3,
#          'resolving to see': 3,
#          'being come to': 3,
#          'i told them': 3,
#          'not daring to': 3,
#          'in stead of': 3,
#          'you can not': 3,
#          'she told me': 3,
#          'had not her': 3,
#          'which she had': 3,
#          'which were not': 3,
#          'c. \n the': 3,
#          'resolving not to': 3,
#          'for which i': 3,
#          'that she should': 3,
#          'she could not': 3,
#          '\n not long': 3,
#          'the old man': 3,
#          'which had so': 3,
#          '\n i believe': 3,
#          'which made him': 3,
#          'had like to': 3,
#          'he could not': 3,
#          'which i thought': 3,
#          'till i had': 3,
#          'and away we': 3,
#          'but he had': 3,
#          'as for his': 3,
#          'for no other': 3,
#          '\n i told': 3,
#          '\n and therefore': 3,
#          'i concluded to': 3,
#          'and it may': 3,
#          'it can not': 3,
#          'that i knew': 3,
#          'wherefore i shall': 3,
#          '\n page 113': 3,
#          'the truth of': 3,
#          'that she might': 3,
#          'as that it': 3,
#          'he answered me': 3,
#          '\n said i': 3,
#          'with which i': 3,
#          'for we had': 3,
#          'to which she': 3,
#          'glad i was': 3,
#          'he brought me': 3,
#          'and that we': 3,
#          '\n i made': 3,
#          'for there is': 3,
#          'i should not': 3,
#          '\n for i': 3,
#          'and so without': 3,
#          '\n i thought': 3,
#          'i thought that': 3,
#          'i met with': 3,
#          '\n after i': 3,
#          '\n at which': 3,
#          'and that it': 3,
#          'but durst not': 3,
#          '\n i found': 3,
#          'as the devil': 3,
#          'i took an': 3,
#          'in a short': 3,
#          'it was a': 3,
#          'they would be': 3,
#          'though i knew': 3,
#          'the young man': 3,
#          'at which he': 3,
#          'which had been': 3,
#          'that he could': 3,
#          'for want of': 3,
#          'which i took': 3,
#          'that since she': 3,
#          'and so left': 3,
#          'and then it': 3,
#          'for by this': 3,
#          'and for the': 3,
#          'and there was': 3,
#          'by the help': 3,
#          'but what i': 3,
#          'so that the': 3,
#          'but she would': 3,
#          'i shall not': 3,
#          'i will not': 3,
#          'and that there': 3,
#          'and if they': 3,
#          'and could not': 3,
#          'the time of': 3,
#          'she would not': 3,
#          'for i had': 3,
#          'for fear of': 3,
#          'though i could': 3,
#          'with much difficulty': 3,
#          'and so they': 3,
#          'it should be': 3,
#          'neither would i': 3,
#          '\n but the': 3,
#          'for he that': 3,
#          'and it will': 3,
#          '\n to conclude': 3,
#          'i needed not': 3,
#          'i now thought': 3,
#          'and that in': 3,
#          '\n by which': 3,
#          'from hence i': 3,
#          'i found it': 3,
#          'after several discourses': 3,
#          'and told me': 3,
#          'and so was': 3,
#          'and then again': 3,
#          'in which the': 3,
#          'c. \n which': 3,
#          'we told them': 3,
#          '\n if you': 3,
#          'under the pretence': 3,
#          'i beseech you': 3,
#          'till they had': 3,
#          'as i had': 3,
#          'tis better so': 3,
#          'but it is': 3,
#          'by which i': 3,
#          '\n in which': 3,
#          'as that we': 3,
#          'assoon as he': 3,
#          'the poor man': 3,
#          'who would be': 3,
#          'whereupon i went': 3,
#          'it would have': 3,
#          'it will not': 3,
#          'in order to': 3,
#          'and make him': 3,
#          'if you have': 3,
#          "i ask'd her": 3,
#          '\n from hence': 3,
#          'in my opinion': 3,
#          '\n or that': 3,
#          'they will pretend': 3,
#          'it is an': 3,
#          'that they may': 3,
#          '\n to make': 3,
#          'he shall not': 3,
#          'in the life': 2,
#          'a witty extravagant': 2,
#          '\n richard head': 2,
#          '\n or else': 2,
#          'but now i': 2,
#          '\n this good': 2,
#          'had not a': 2,
#          '\n when i': 2,
#          '\n on the': 2,
#          '\n i now': 2,
#          'now i think': 2,
#          '\n of all': 2,
#          '\n and other': 2,
#          '\n for thou': 2,
#          '\n this \n': 2,
#          'being a compleat': 2,
#          'written by \n': 2,
#          'and will be': 2,
#          '\n page 1': 2,
#          'but if the': 2,
#          'i believe i': 2,
#          'neither could they': 2,
#          'and to say': 2,
#          'by the strength': 2,
#          'in a very': 2,
#          'thus you see': 2,
#          'but without a': 2,
#          'and now and': 2,
#          'and then would': 2,
#          '\n which the': 2,
#          'this i have': 2,
#          'and being in': 2,
#          'to hear how': 2,
#          'as they judged': 2,
#          'the old people': 2,
#          'and my mother': 2,
#          '\n but not': 2,
#          'neither shall i': 2,
#          'for to speak': 2,
#          'age to the': 2,
#          'or the least': 2,
#          'by break of': 2,
#          'took his leave': 2,
#          'and returned to': 2,
#          'till the \n': 2,
#          '\n page 11': 2,
#          'so great an': 2,
#          'who were able': 2,
#          '\n that the': 2,
#          '◊ ◊ ◊': 2,
#          'i shall relate': 2,
#          'i must confess': 2,
#          '\n who presently': 2,
#          '\n sir \n': 2,
#          'as it was': 2,
#          'the terror of': 2,
#          'and in stead': 2,
#          'and so led': 2,
#          '\n then did': 2,
#          'which being done': 2,
#          'to repair the': 2,
#          '\n there being': 2,
#          'to repair what': 2,
#          'from hence we': 2,
#          '\n so called': 2,
#          '\n unto which': 2,
#          '\n but she': 2,
#          'with which we': 2,
#          'i was ten': 2,
#          'we at last': 2,
#          'so that in': 2,
#          'where i had': 2,
#          'i would make': 2,
#          'and having so': 2,
#          'you must think': 2,
#          'which were so': 2,
#          'if i could': 2,
#          'if i met': 2,
#          'i had my': 2,
#          'for he hath': 2,
#          'here is another': 2,
#          '\n page 23': 2,
#          'as we had': 2,
#          'and pretending to': 2,
#          'i demanded of': 2,
#          'and took up': 2,
#          'i desired the': 2,
#          'whereupon i related': 2,
#          'flow with the': 2,
#          'a man of': 2,
#          'having put in': 2,
#          'which with much': 2,
#          'and carried it': 2,
#          'i got into': 2,
#          'thinking my self': 2,
#          'i went in': 2,
#          'attended with a': 2,
#          "as he call'd": 2,
#          'but when she': 2,
#          '\n and my': 2,
#          'fell down as': 2,
#          'she knew not': 2,
#          '\n and to': 2,
#          'against the time': 2,
#          'which was done': 2,
#          'that another time': 2,
#          'whom i had': 2,
#          '\n she said': 2,
#          'and bid me': 2,
#          '\n that it': 2,
#          'but the next': 2,
#          'though i was': 2,
#          'when they were': 2,
#          'thinking i should': 2,
#          'instead of a': 2,
#          'i laid my': 2,
#          'for the day': 2,
#          '\n and with': 2,
#          'and so fell': 2,
#          'and finding me': 2,
#          'this was a': 2,
#          'in so much': 2,
#          'and to make': 2,
#          'as they called': 2,
#          'yet i was': 2,
#          'as not to': 2,
#          '\n being now': 2,
#          'one of our': 2,
#          'then would they': 2,
#          'and because it': 2,
#          '\n i know': 2,
#          'you have lost': 2,
#          'or any such': 2,
#          'came to him': 2,
#          'but before he': 2,
#          'but to return': 2,
#          'and in our': 2,
#          'that nothing would': 2,
#          'or else they': 2,
#          'as never to': 2,
#          'but let the': 2,
#          'and leave the': 2,
#          'this being done': 2,
#          'being loath to': 2,
#          '\n for all': 2,
#          '\n i met': 2,
#          '\n she was': 2,
#          'then did we': 2,
#          'male and female': 2,
#          'by this means': 2,
#          'there hath not': 2,
#          'and no wonder': 2,
#          '\n we use': 2,
#          'it is enough': 2,
#          '\n i resolved': 2,
#          'and though he': 2,
#          'till they have': 2,
#          'for as soon': 2,
#          'and she not': 2,
#          '\n he would': 2,
#          '\n if any': 2,
#          'that we should': 2,
#          'shewing my self': 2,
#          'as that you': 2,
#          '\n being full': 2,
#          'which was a': 2,
#          'i askt them': 2,
#          'and of a': 2,
#          'to be short': 2,
#          'he was so': 2,
#          'he got a': 2,
#          'that the \n': 2,
#          'that i found': 2,
#          'which was thus': 2,
#          'but in the': 2,
#          'we fell into': 2,
#          'we have been': 2,
#          'it shall not': 2,
#          'and askt him': 2,
#          'i am going': 2,
#          'and demanding of': 2,
#          '\n page 61': 2,
#          '\n coming to': 2,
#          '\n but by': 2,
#          'he needed not': 2,
#          'and thus they': 2,
#          'which in a': 2,
#          '\n with a': 2,
#          'coming into the': 2,
#          'the first thing': 2,
#          'to which he': 2,
#          'when all the': 2,
#          'though they were': 2,
#          'but i must': 2,
#          'they were so': 2,
#          '\n you must': 2,
#          'i sent to': 2,
#          'and without any': 2,
#          '\n page 65': 2,
#          'and in \n': 2,
#          'which accordingly i': 2,
#          'at length i': 2,
#          'that my master': 2,
#          'come give me': 2,
#          'whilst she was': 2,
#          'as in the': 2,
#          'at last she': 2,
#          'the first that': 2,
#          'for a little': 2,
#          'we went to': 2,
#          'we were so': 2,
#          'i found the': 2,
#          '\n one time': 2,
#          'and fell into': 2,
#          'for as i': 2,
#          'here is a': 2,
#          '\n one day': 2,
#          'yet knew not': 2,
#          'neither would they': 2,
#          'he asked me': 2,
#          'what shall i': 2,
#          'for i am': 2,
#          'this shall be': 2,
#          'neither can i': 2,
#          'unless necessity required': 2,
#          'but then it': 2,
#          'but all this': 2,
#          'which puts me': 2,
#          'and his master': 2,
#          '\n now to': 2,
#          '\n let me': 2,
#          '\n we are': 2,
#          'as he said': 2,
#          'order was given': 2,
#          'but i heard': 2,
#          '\n page 77': 2,
#          'bottle in his': 2,
#          '\n using your': 2,
#          '\n but if': 2,
#          'to make the': 2,
#          'he would not': 2,
#          'having no other': 2,
#          'he informed me': 2,
#          'that all my': 2,
#          'c. \n if': 2,
#          '\n page 79': 2,
#          'though to the': 2,
#          'take too much': 2,
#          'taking notice of': 2,
#          'as i said': 2,
#          'and all things': 2,
#          'i acquainted her': 2,
#          'the first time': 2,
#          'some of them': 2,
#          'which is the': 2,
#          'but that we': 2,
#          'so that this': 2,
#          '\n said my': 2,
#          '\n i have': 2,
#          '\n i durst': 2,
#          'i made an': 2,
#          'at length she': 2,
#          'i must have': 2,
#          'and was overjoyed': 2,
#          'she bid me': 2,
#          'and his own': 2,
#          'or the like': 2,
#          'half a dozen': 2,
#          '\n page 87': 2,
#          'i never came': 2,
#          'she resolved to': 2,
#          'the old bawd': 2,
#          '\n she had': 2,
#          'this gentleman was': 2,
#          'could do no': 2,
#          'neither could she': 2,
#          'as long as': 2,
#          'a gentlewoman of': 2,
#          'that they made': 2,
#          'and fearing lest': 2,
#          'who had not': 2,
#          'and the better': 2,
#          'for two or': 2,
#          'as he was': 2,
#          'for instead of': 2,
#          'and indeed i': 2,
#          'that it would': 2,
#          'but i thought': 2,
#          'i came home': 2,
#          '\n i should': 2,
#          '\n page 99': 2,
#          '\n whom he': 2,
#          'if he chance': 2,
#          'he is the': 2,
#          'he is very': 2,
#          'and full of': 2,
#          'till all the': 2,
#          'and after many': 2,
#          'i could have': 2,
#          'and we will': 2,
#          'and found it': 2,
#          '\n page 105': 2,
#          'i applyed my': 2,
#          'i repaired to': 2,
#          'approaching the bed': 2,
#          'but considering that': 2,
#          'which should be': 2,
#          'i had just': 2,
#          'the result of': 2,
#          'which he readily': 2,
#          'which i could': 2,
#          'so that at': 2,
#          'which i was': 2,
#          'and one that': 2,
#          'some of the': 2,
#          'if it be': 2,
#          'unless i should': 2,
#          'though never so': 2,
#          'that it is': 2,
#          'we were conducted': 2,
#          'and began to': 2,
#          'neither shall you': 2,
#          'if you want': 2,
#          'for she did': 2,
#          '\n page 115': 2,
#          'that you may': 2,
#          'and no more': 2,
#          'that as the': 2,
#          'and now i': 2,
#          'leaving the old': 2,
#          'the more he': 2,
#          'if there be': 2,
#          'i think she': 2,
#          'i lookt about': 2,
#          'since there was': 2,
#          'i askt her': 2,
#          'fearing i should': 2,
#          'and then with': 2,
#          'not but that': 2,
#          'i consulted with': 2,
#          'and requested the': 2,
#          '\n i gave': 2,
#          'i shall leave': 2,
#          'but she told': 2,
#          'but then i': 2,
#          'at which i': 2,
#          'i might have': 2,
#          'and so slid': 2,
#          'and one of': 2,
#          'she begged me': 2,
#          'she was very': 2,
#          'and i am': 2,
#          'i asked her': 2,
#          'with all the': 2,
#          'i thought the': 2,
#          'in this disguize': 2,
#          'was now ready': 2,
#          'though with much': 2,
#          '\n and have': 2,
#          'i believe he': 2,
#          'i durst not': 2,
#          'pretending i had': 2,
#          'that with much': 2,
#          'but that she': 2,
#          'fear had so': 2,
#          'but to be': 2,
#          'and then i': 2,
#          'they could not': 2,
#          'whereupon i told': 2,
#          'and it was': 2,
#          'the good old': 2,
#          'giving a general': 2,
#          'one night i': 2,
#          'till at last': 2,
#          'for so i': 2,
#          'so did it': 2,
#          'that i know': 2,
#          'for her own': 2,
#          'and i was': 2,
#          'that would not': 2,
#          'that she did': 2,
#          'which was no': 2,
#          'i judged it': 2,
#          '\n what i': 2,
#          '\n she answered': 2,
#          'you shall not': 2,
#          '\n i answered': 2,
#          'and i hope': 2,
#          '\n here he': 2,
#          'but the consideration': 2,
#          'or else i': 2,
#          'wherefore i resolved': 2,
#          'which was all': 2,
#          'i vowed to': 2,
#          'knowing that a': 2,
#          'neither durst i': 2,
#          'my belly began': 2,
#          'that i did': 2,
#          'that i durst': 2,
#          'but when the': 2,
#          'which was very': 2,
#          "i call'd for": 2,
#          'for said she': 2,
#          '\n for what': 2,
#          'dost thou think': 2,
#          'and thinking the': 2,
#          'in this condition': 2,
#          'and being not': 2,
#          'for had i': 2,
#          'in the form': 2,
#          'and laying hold': 2,
#          'laying my hand': 2,
#          'but before we': 2,
#          'which i shall': 2,
#          'i could but': 2,
#          '\n he carried': 2,
#          'and then to': 2,
#          'i thought he': 2,
#          'and that \n': 2,
#          '\n yet it': 2,
#          '\n then to': 2,
#          '\n i might': 2,
#          'that night i': 2,
#          '\n i began': 2,
#          'which otherwise would': 2,
#          'at first sight': 2,
#          'by the way': 2,
#          'whom i understood': 2,
#          '\n but that': 2,
#          'i asked him': 2,
#          'but i am': 2,
#          'which had like': 2,
#          'and all this': 2,
#          'but in my': 2,
#          'which i made': 2,
#          'who told me': 2,
#          '\n or an': 2,
#          '\n and shall': 2,
#          '\n when the': 2,
#          '\n full fraught': 2,
#          'i was conducted': 2,
#          'as it doth': 2,
#          'if you can': 2,
#          'i perceived by': 2,
#          'she might have': 2,
#          'for that was': 2,
#          'for you are': 2,
#          'i thought you': 2,
#          'i used all': 2,
#          '\n having gained': 2,
#          'it is but': 2,
#          'but above all': 2,
#          'have a special': 2,
#          'according to my': 2,
#          'but before i': 2,
#          'my mistress had': 2,
#          'and not daring': 2,
#          'a little after': 2,
#          'with much ado': 2,
#          'as if a': 2,
#          'for there were': 2,
#          'for he had': 2,
#          'as if \n': 2,
#          'i confess i': 2,
#          'coming to the': 2,
#          'and then those': 2,
#          'which i had': 2,
#          'for by that': 2,
#          'and so by': 2,
#          'and then the': 2,
#          'and in what': 2,
#          'but if he': 2,
#          'she would say': 2,
#          '\n for my': 2,
#          'i could do': 2,
#          'neither was it': 2,
#          'and to be': 2,
#          '\n with \n': 2,
#          'he gave me': 2,
#          'fearing least i': 2,
#          'how could i': 2,
#          'though i had': 2,
#          '\n to be': 2,
#          'i sent my': 2,
#          '\n as yet': 2,
#          'let each man': 2,
#          'the best way': 2,
#          'knowing it could': 2,
#          'and from that': 2,
#          'before i was': 2,
#          'seeing there was': 2,
#          'knowing very well': 2,
#          'i went down': 2,
#          'with that she': 2,
#          'i took it': 2,
#          'i was too': 2,
#          'which i might': 2,
#          'having made my': 2,
#          '\n but now': 2,
#          '\n so that': 2,
#          'if i was': 2,
#          'and so resolved': 2,
#          '\n but his': 2,
#          'at last it': 2,
#          'intending to make': 2,
#          'at which they': 2,
#          'to know what': 2,
#          'that had i': 2,
#          '\n and what': 2,
#          '\n a new': 2,
#          'tis strange that': 2,
#          'had not my': 2,
#          'when i lookt': 2,
#          'a kind of': 2,
#          '\n but i': 2,
#          'and when you': 2,
#          'you must be': 2,
#          'if you will': 2,
#          'what might be': 2,
#          'but i never': 2,
#          'for i have': 2,
#          'whom i knew': 2,
#          ...})

# %%
with open(f"{nome_file}.{n}grams.csv", "w") as fout:
    fout.write("Item, Frequency\n")
    fout.writelines([f'"{k}", {v}\n' for k, v in num_gram.most_common()])
